# %%
class NameOfClass:
    def __init__(self, param1, param2):
        self.param1 = param1
        self.param2 = param2

    def some_method(self):
        # perform some action
        print(self.param1)

# %%
class Dog:
    # Class Object Attribute
    species = "mammal"

    def __init__(self, mybreed, name):
        self.breed = mybreed
        self.name = name

    def bark(self, number):
        print("WOOF! My name is {} and the number is {}".format(self.name, number))


my_dog = Dog("Lab", "Frankie")

my_dog.bark(3)  # WOOF! My name is Frankie and the number is 3
# Out:
# WOOF! My name is Frankie and the number is 3

# %%
class Circle:
    # Class Object Attribute
    pi = 3.14

    def __init__(self, radius=1):  # default value
        self.radius = radius
        self.area = radius * radius * self.pi

    # Method
    def get_circumference(self):
        return self.radius * self.pi * 2

# %%
class Circle:
    # Class Object Attribute
    pi = 3.14

    def __init__(self, radius=1):
        self.radius = radius
        self.area = radius * radius * Circle.pi

    # Method
    def get_circumference(self):
        return self.radius * Circle.pi * 2

# %%
class Animal:
    def __init__(self):  # 3
        print("ANIMAL CREATED")  # 4

    def who_am_i(self):
        print("I am an animal")

    def eat(self):
        print("I am eating")


class Dog(Animal):
    def __init__(self):  # 1
        Animal.__init__(self)  # 2 inheritance
        print("Dog Created")  # 5

    def who_am_i(self):  # override who_am_i from Animal class
        print("I am a dog!")


mydog = Dog()
"""
ANIMAL CREATED
Dog Created
"""
mydog.eat()  # inheritance
"""
I am eating
"""

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says woof!"


class Cat:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says meow!"


niko = Dog("niko")
felix = Cat("felix")

print(niko.speak())  # niko says woof!
print(felix.speak())  # felix says meow!

for pet in [niko, felix]:
    print(type(pet))
    print(pet.speak())
"""
<class '__main__.Dog'>
niko says woof!
<class '__main__.Cat'>
felix says meow!
"""


def pet_speak(pet):
    print(pet.speak())


pet_speak(niko)  # niko says woof!
pet_speak(felix)  # felix says meow!
# Out:
# niko says woof!
# felix says meow!
# <class '__main__.Dog'>
# niko says woof!
# <class '__main__.Cat'>
# felix says meow!
# niko says woof!
# felix says meow!

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):  # abstract method
        raise NotImplementedError("Subclass must implement this abstract method")


myanimal = Animal("fred")
# myanimal.speak() # error occurred


class Dog(Animal):
    def speak(self):  # method override
        return self.name + " says woof!"


class Cat(Animal):
    def speak(self):  # method override
        return self.name + " says meow!"


fido = Dog("Fido")
isis = Cat("Isis")

print(fido.speak())  # Fido says woof!
print(isis.speak())  # Isis says meow!
# Out:
# Fido says woof!
# Isis says meow!

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages


b = Book("Python rocks", "Jose", 200)
print(b)  # <__main__.Book object at 0x1066db4c0>
str(b)  # '<__main__.Book object at 0x1066db4c0>'
# Out:
# ...
# '<__main__.Book object at 0x1062ba3d0>'

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):  # special method
        return f"{self.title} by {self.author}"


b = Book("Python rocks", "Jose", 200)
print(b)  # Python rocks by Jose
str(b)  # 'Python rocks by Jose'
# Out:
# Python rocks by Jose
# 'Python rocks by Jose'

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"{self.title} by {self.author}"


b = Book("Python rocks", "Jose", 200)
len(b)  # TypeError: object of type 'Book' has no len()Cell Execution Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 12
#       8         return f"{self.title} by {self.author}"
#      11 b = Book("Python rocks", "Jose", 200)
# ---> 12 len(b)
#
# TypeError: object of type 'Book' has no len()

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"{self.title} by {self.author}"

    def __len__(self):  # special method
        return self.pages


b = Book("Python rocks", "Jose", 200)
len(b)  # 200
# Out:
# 200

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"{self.title} by {self.author}"

    def __len__(self):
        return self.pages

    def __del__(self):
        print("A book object has been deleted")


b = Book("Python rocks", "Jose", 200)
del b  # A book object has been deleted
# Out:
# A book object has been deleted

# %%
2 == 1
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
2 < 3 > 1
# Out:
# True

# %%
"h" == "h" and 2 == 2
# Out:
# True

# %%
False or print("hello world")
# Out:
# hello world

# %%
100 == 100 or False
# Out:
# True

# %%
False and print("ha")
# Out:
# False

# %%
not (1 == 1)
# Out:
# False
